# %% [markdown]
# IFC TO GRAPH

# %%
import ifcopenshell
import networkx as nx
import matplotlib.pyplot as plt
import math
from matplotlib.animation import FuncAnimation

def add_to_graph(existing, new, edge_label, G):
    G.add_node(new.id(), **new.get_info())
    G.add_edge(existing.id(), new.id(), weight=7, edge_label=edge_label)

def is_entity_instance(val):
    return val.id() != 0 and isinstance(val, ifcopenshell.entity_instance)

def get_global_coordinates(entity):
    placement = getattr(entity, 'ObjectPlacement', None)
    if placement and placement.is_a('IfcLocalPlacement'):
        relative_placement = placement.RelativePlacement
        if relative_placement and relative_placement.is_a('IfcAxis2Placement3D'):
            location = relative_placement.Location
            if location and hasattr(location, 'Coordinates'):
                return tuple(location.Coordinates)
    return (0.0, 0.0, 0.0)

def calculate_distance(coord1, coord2):
    return math.sqrt(sum((c2 - c1) ** 2 for c1, c2 in zip(coord1, coord2)))

def preprocess_graph_attributes(G):
    for node, data in G.nodes(data=True):
        # Convert non-serializable attributes to strings or remove them
        for key, value in list(data.items()):
            if not isinstance(value, (str, int, float, bool, type(None))):
                data[key] = str(value)

    for u, v, data in G.edges(data=True):
        # Convert non-serializable edge attributes
        for key, value in list(data.items()):
            if not isinstance(value, (str, int, float, bool, type(None))):
                data[key] = str(value)

def create_graph(ifc_file):
    G = nx.DiGraph()
    element_coords = {}

    wall_ids = []
    door_ids = []
    room_ids = []

    for entity in ifc_file:
        info = entity.get_info()

        # Filter walls, doors, and rooms
        if entity.is_a("IfcWallStandardCase") or entity.is_a("IfcWall"):
            wall_ids.append(entity.id())
            G.add_node(entity.id(), **entity.get_info())
            element_coords[entity.id()] = get_global_coordinates(entity)

        elif entity.is_a("IfcDoor"):
            door_ids.append(entity.id())
            G.add_node(entity.id(), **entity.get_info())
            element_coords[entity.id()] = get_global_coordinates(entity)

        elif entity.is_a("IfcSpace"):
            room_ids.append(entity.id())
            room_name = getattr(entity, 'Name', f"Room_{entity.id()}")  # Use the architect-specified name
            G.add_node(entity.id(), **entity.get_info(), label=room_name)  # Add the room name as a label
            element_coords[entity.id()] = get_global_coordinates(entity)

    # Add edges only between walls, doors, and rooms with distance calculation
    for wall in wall_ids:
        for door in door_ids:
            coord1 = element_coords.get(wall, (0.0, 0.0, 0.0))
            coord2 = element_coords.get(door, (0.0, 0.0, 0.0))
            distance = calculate_distance(coord1, coord2)
            G.add_edge(wall, door, edge_label=f"Distance: {distance:.2f}")

        for room in room_ids:
            coord1 = element_coords.get(wall, (0.0, 0.0, 0.0))
            coord2 = element_coords.get(room, (0.0, 0.0, 0.0))
            distance = calculate_distance(coord1, coord2)
            G.add_edge(wall, room, edge_label=f"Distance: {distance:.2f}")

    for door in door_ids:
        for room in room_ids:
            coord1 = element_coords.get(door, (0.0, 0.0, 0.0))
            coord2 = element_coords.get(room, (0.0, 0.0, 0.0))
            distance = calculate_distance(coord1, coord2)
            G.add_edge(door, room, edge_label=f"Distance: {distance:.2f}")

    return G

def draw_graph(G, layout='shell'):
    labels = {}
    for n in G.nodes.values():
        labels[n['id']] = "#" + str(n['id']) + "\n" + n['type']
    cm = []
    for n in G.nodes.values():
        cm.append((1, 1, 0.8))

    edges_labels = {}
    for e in G.edges().data():
        edges_labels[(e[0], e[1])] = e[2]["edge_label"]

    if layout == 'shell':
        pos = nx.shell_layout(G)
    elif layout == 'random':
        pos = nx.random_layout(G)
    else:
        pos = nx.spring_layout(G, k=0.6, iterations=3)

    nx.draw_networkx_nodes(G, pos, nodelist=G.nodes, node_color=cm, node_size=20, node_shape='o')
    nx.draw_networkx_edges(G, pos, edgelist=G.edges, arrows=True, alpha=0.5)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edges_labels, font_size=.01)
    nx.draw_networkx_labels(G, pos, labels=labels, verticalalignment='top', font_size=3)

    plt.axis("off")
    plt.show()

def save_graph_as_gif(G, output_path, frames=50):
    fig, ax = plt.subplots(figsize=(10, 7))

    pos = nx.spring_layout(G, seed=42)

    def update(frame):
        ax.clear()
        updated_pos = {node: (coord[0] + 0.01 * frame, coord[1]) for node, coord in pos.items()}
        nx.draw(G, updated_pos, with_labels=True, ax=ax, node_size=20, font_size=2, edge_color="gray", node_color="blue")
        ax.set_title(f"Frame {frame + 1}/{frames}")

    ani = FuncAnimation(fig, update, frames=frames, interval=200, repeat=False)
    ani.save(output_path, writer="pillow")

if __name__ == "__main__":

    ifc_file_path = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\floorplanexampleroomswithnames.ifc'

    try:
        ifc_file = ifcopenshell.open(ifc_file_path)
    except Exception as e:
        raise FileNotFoundError(f"Error opening IFC file: {e}")

    # Create graph for walls, doors, and rooms
    G = create_graph(ifc_file)

    # Preprocess the graph attributes to ensure compatibility
    preprocess_graph_attributes(G)

    # Print vertices
    print("Vertices:")
    for node_id, data in G.nodes(data=True):
        print(f"Node ID: {node_id}, Data: {data}")

    # Print edges
    print("\nEdges:")
    for u, v, data in G.edges(data=True):
        print(f"Edge from {u} to {v}, Data: {data}")

    # Draw the graph
    draw_graph(G, layout='shell')
# Out:
# Vertices:
# Node ID: 2321, Data: {'id': 2321, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVlI', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3049=IfcLocalPlacement(#3039,#3048)', 'Representation': '#2317=IfcProductDefinitionShape($,$,(#2316))', 'Tag': '1664109', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2286, Data: {'id': 2286, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVkU', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3029=IfcLocalPlacement(#3019,#3028)', 'Representation': '#2282=IfcProductDefinitionShape($,$,(#2281))', 'Tag': '1664033', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000017}
# Node ID: 2251, Data: {'id': 2251, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVn0', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3009=IfcLocalPlacement(#2999,#3008)', 'Representation': '#2247=IfcProductDefinitionShape($,$,(#2246))', 'Tag': '1663999', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000017}
# Node ID: 2216, Data: {'id': 2216, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVm6', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2989=IfcLocalPlacement(#2979,#2988)', 'Representation': '#2212=IfcProductDefinitionShape($,$,(#2211))', 'Tag': '1663929', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2181, Data: {'id': 2181, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVpw', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2969=IfcLocalPlacement(#2959,#2968)', 'Representation': '#2177=IfcProductDefinitionShape($,$,(#2176))', 'Tag': '1663813', 'OverallHeight': 2100.0, 'OverallWidth': 849.9999999999995}
# Node ID: 2146, Data: {'id': 2146, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVou', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2929=IfcLocalPlacement(#2919,#2928)', 'Representation': '#2142=IfcProductDefinitionShape($,$,(#2141))', 'Tag': '1663751', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000006}
# Node ID: 2111, Data: {'id': 2111, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVr_', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2949=IfcLocalPlacement(#2939,#2948)', 'Representation': '#2107=IfcProductDefinitionShape($,$,(#2106))', 'Tag': '1663681', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2049, Data: {'id': 2049, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVqh', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2909=IfcLocalPlacement(#2899,#2908)', 'Representation': '#2045=IfcProductDefinitionShape($,$,(#2044))', 'Tag': '1663636', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 1587, Data: {'id': 1587, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyS8f', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1575=IfcLocalPlacement(#34,#1574)', 'Representation': '#1586=IfcProductDefinitionShape($,$,(#1578,#1585))', 'Tag': '1662358'}
# Node ID: 1544, Data: {'id': 1544, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySAE', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1532=IfcLocalPlacement(#34,#1531)', 'Representation': '#1543=IfcProductDefinitionShape($,$,(#1535,#1542))', 'Tag': '1662257'}
# Node ID: 1501, Data: {'id': 1501, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySFq', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1489=IfcLocalPlacement(#34,#1488)', 'Representation': '#1500=IfcProductDefinitionShape($,$,(#1492,#1499))', 'Tag': '1662027'}
# Node ID: 1458, Data: {'id': 1458, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySGS', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1446=IfcLocalPlacement(#34,#1445)', 'Representation': '#1457=IfcProductDefinitionShape($,$,(#1449,#1456))', 'Tag': '1661859'}
# Node ID: 1372, Data: {'id': 1372, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySLf', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1360=IfcLocalPlacement(#34,#1359)', 'Representation': '#1371=IfcProductDefinitionShape($,$,(#1363,#1370))', 'Tag': '1661654'}
# Node ID: 1329, Data: {'id': 1329, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySNJ', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1317=IfcLocalPlacement(#34,#1316)', 'Representation': '#1328=IfcProductDefinitionShape($,$,(#1320,#1327))', 'Tag': '1661548'}
# Node ID: 1286, Data: {'id': 1286, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySML', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1274=IfcLocalPlacement(#34,#1273)', 'Representation': '#1285=IfcProductDefinitionShape($,$,(#1277,#1284))', 'Tag': '1661482'}
# Node ID: 1243, Data: {'id': 1243, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySPs', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1231=IfcLocalPlacement(#34,#1230)', 'Representation': '#1242=IfcProductDefinitionShape($,$,(#1234,#1241))', 'Tag': '1661385'}
# Node ID: 1200, Data: {'id': 1200, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySR7', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1188=IfcLocalPlacement(#34,#1187)', 'Representation': '#1199=IfcProductDefinitionShape($,$,(#1191,#1198))', 'Tag': '1661304'}
# Node ID: 1157, Data: {'id': 1157, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySaA', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1145=IfcLocalPlacement(#34,#1144)', 'Representation': '#1156=IfcProductDefinitionShape($,$,(#1148,#1155))', 'Tag': '1660597'}
# Node ID: 1114, Data: {'id': 1114, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySdv', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1102=IfcLocalPlacement(#34,#1101)', 'Representation': '#1113=IfcProductDefinitionShape($,$,(#1105,#1112))', 'Tag': '1660486'}
# Node ID: 1071, Data: {'id': 1071, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyScM', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1059=IfcLocalPlacement(#34,#1058)', 'Representation': '#1070=IfcProductDefinitionShape($,$,(#1062,#1069))', 'Tag': '1660457'}
# Node ID: 1028, Data: {'id': 1028, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySeJ', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1016=IfcLocalPlacement(#34,#1015)', 'Representation': '#1027=IfcProductDefinitionShape($,$,(#1019,#1026))', 'Tag': '1660332'}
# Node ID: 942, Data: {'id': 942, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySg$', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#930=IfcLocalPlacement(#34,#929)', 'Representation': '#941=IfcProductDefinitionShape($,$,(#933,#940))', 'Tag': '1660160'}
# Node ID: 899, Data: {'id': 899, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySkG', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#887=IfcLocalPlacement(#34,#886)', 'Representation': '#898=IfcProductDefinitionShape($,$,(#890,#897))', 'Tag': '1659951'}
# Node ID: 813, Data: {'id': 813, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySmj', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#801=IfcLocalPlacement(#34,#800)', 'Representation': '#812=IfcProductDefinitionShape($,$,(#804,#811))', 'Tag': '1659794'}
# Node ID: 770, Data: {'id': 770, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySr2', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#758=IfcLocalPlacement(#34,#757)', 'Representation': '#769=IfcProductDefinitionShape($,$,(#761,#768))', 'Tag': '1659645'}
# Node ID: 663, Data: {'id': 663, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySwl', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#651=IfcLocalPlacement(#34,#650)', 'Representation': '#662=IfcProductDefinitionShape($,$,(#654,#661))', 'Tag': '1659152'}
# Node ID: 577, Data: {'id': 577, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySy4', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Concrete 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Concrete 300mm', 'ObjectPlacement': '#561=IfcLocalPlacement(#34,#560)', 'Representation': '#576=IfcProductDefinitionShape($,$,(#564,#575))', 'Tag': '1659067'}
# Node ID: 522, Data: {'id': 522, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyS_Q', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#510=IfcLocalPlacement(#34,#509)', 'Representation': '#521=IfcProductDefinitionShape($,$,(#513,#520))', 'Tag': '1658917'}
# Node ID: 1415, Data: {'id': 1415, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySIs', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1403=IfcLocalPlacement(#34,#1402)', 'Representation': '#1414=IfcProductDefinitionShape($,$,(#1406,#1413))', 'Tag': '1661705'}
# Node ID: 985, Data: {'id': 985, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyShr', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#973=IfcLocalPlacement(#34,#972)', 'Representation': '#984=IfcProductDefinitionShape($,$,(#976,#983))', 'Tag': '1660234'}
# Node ID: 372, Data: {'id': 372, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVN', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '106', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#364=IfcLocalPlacement(#34,#363)', 'Representation': '#371=IfcProductDefinitionShape($,$,(#370))', 'LongName': 'Exam room 5', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '106'}
# Node ID: 326, Data: {'id': 326, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVI', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '105', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#318=IfcLocalPlacement(#34,#317)', 'Representation': '#325=IfcProductDefinitionShape($,$,(#324))', 'LongName': 'Exam room 4', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '105'}
# Node ID: 280, Data: {'id': 280, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVH', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '104', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#267=IfcLocalPlacement(#34,#266)', 'Representation': '#279=IfcProductDefinitionShape($,$,(#278))', 'LongName': 'Exam room 3', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '104'}
# Node ID: 1871, Data: {'id': 1871, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyS5V', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Double-Flush : 1700 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Double-Flush:1700 x 2000mm', 'ObjectPlacement': '#2889=IfcLocalPlacement(#2879,#2888)', 'Representation': '#1867=IfcProductDefinitionShape($,$,(#1866))', 'Tag': '1662688', 'OverallHeight': 2100.0, 'OverallWidth': 1799.9999999999989}
# Node ID: 856, Data: {'id': 856, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySn5', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#844=IfcLocalPlacement(#34,#843)', 'Representation': '#855=IfcProductDefinitionShape($,$,(#847,#854))', 'Tag': '1659898'}
# Node ID: 229, Data: {'id': 229, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVC', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '103', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#221=IfcLocalPlacement(#34,#220)', 'Representation': '#228=IfcProductDefinitionShape($,$,(#227))', 'LongName': 'Reception', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '103'}
# Node ID: 1795, Data: {'id': 1795, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyS6y', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Double-Flush : 1700 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Double-Flush:1700 x 2000mm', 'ObjectPlacement': '#2869=IfcLocalPlacement(#2859,#2868)', 'Representation': '#1791=IfcProductDefinitionShape($,$,(#1790))', 'Tag': '1662467', 'OverallHeight': 2100.0, 'OverallWidth': 1799.9999999999995}
# Node ID: 183, Data: {'id': 183, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVB', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '102', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#175=IfcLocalPlacement(#34,#174)', 'Representation': '#182=IfcProductDefinitionShape($,$,(#181))', 'LongName': 'Exam room 2', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '102'}
# Node ID: 137, Data: {'id': 137, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJV6', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '101', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#129=IfcLocalPlacement(#34,#128)', 'Representation': '#136=IfcProductDefinitionShape($,$,(#135))', 'LongName': 'Toilet', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '101'}
# Node ID: 706, Data: {'id': 706, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySqF', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#694=IfcLocalPlacement(#34,#693)', 'Representation': '#705=IfcProductDefinitionShape($,$,(#697,#704))', 'Tag': '1659568'}
# Node ID: 65, Data: {'id': 65, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJV5', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '100', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#57=IfcLocalPlacement(#34,#56)', 'Representation': '#64=IfcProductDefinitionShape($,$,(#63))', 'LongName': 'Exam room 1', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '100'}
# Node ID: 427, Data: {'id': 427, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyT1P', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#411=IfcLocalPlacement(#34,#410)', 'Representation': '#426=IfcProductDefinitionShape($,$,(#414,#425))', 'Tag': '1658854'}
#
# Edges:
# Edge from 2321 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1587 to 2321, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2286, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2251, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2216, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2181, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2146, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2111, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2049, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 1871, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 1795, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 372, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 326, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 280, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 229, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 183, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 137, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 65, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1544 to 2321, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2286, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2251, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2216, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2181, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2146, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2111, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2049, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 1871, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 1795, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 372, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 326, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 280, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 229, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 183, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 137, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 65, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1501 to 2321, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2286, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2251, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2216, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2181, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2146, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2111, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2049, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 1871, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 1795, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 372, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 326, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 280, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 229, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 183, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 137, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 65, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1458 to 2321, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2286, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2251, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2216, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2181, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2146, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2111, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2049, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 1871, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 1795, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 372, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 326, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 280, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 229, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 183, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 137, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 65, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1372 to 2321, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2286, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2251, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2216, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2181, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2146, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2111, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2049, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 1871, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 1795, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 372, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 326, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 280, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 229, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 183, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 137, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 65, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1329 to 2321, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2286, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2251, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2216, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2181, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2146, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2111, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2049, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 1871, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 1795, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 372, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 326, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 280, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 229, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 183, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 137, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 65, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1286 to 2321, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2286, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2251, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2216, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2181, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2146, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2111, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2049, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 1871, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 1795, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 372, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 326, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 280, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 229, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 183, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 137, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 65, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1243 to 2321, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2286, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2251, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2216, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2181, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2146, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2111, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2049, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 1871, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 1795, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 372, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 326, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 280, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 229, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 183, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 137, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 65, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1200 to 2321, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2286, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2251, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2216, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2181, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2146, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2111, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2049, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 1871, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 1795, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 372, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 326, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 280, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 229, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 183, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 137, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 65, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1157 to 2321, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2286, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2251, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2216, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2181, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2146, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2111, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2049, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 1871, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 1795, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 372, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 326, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 280, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 229, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 183, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 137, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 65, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1114 to 2321, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2286, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2251, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2216, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2181, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2146, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2111, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2049, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 1871, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 1795, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 372, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 326, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 280, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 229, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 183, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 137, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 65, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1071 to 2321, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2286, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2251, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2216, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2181, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2146, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2111, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2049, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 1871, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 1795, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 372, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 326, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 280, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 229, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 183, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 137, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 65, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1028 to 2321, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2286, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2251, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2216, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2181, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2146, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2111, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2049, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 1871, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 1795, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 372, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 326, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 280, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 229, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 183, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 137, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 65, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 942 to 2321, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2286, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2251, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2216, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2181, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2146, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2111, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2049, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 1871, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 1795, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 372, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 326, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 280, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 229, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 183, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 137, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 65, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 899 to 2321, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2286, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2251, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2216, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2181, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2146, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2111, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2049, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 1871, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 1795, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 372, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 326, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 280, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 229, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 183, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 137, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 65, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 813 to 2321, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2286, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2251, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2216, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2181, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2146, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2111, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2049, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 1871, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 1795, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 372, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 326, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 280, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 229, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 183, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 137, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 65, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 770 to 2321, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2286, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2251, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2216, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2181, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2146, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2111, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2049, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 1871, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 1795, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 372, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 326, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 280, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 229, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 183, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 137, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 65, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 663 to 2321, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2286, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2251, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2216, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2181, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2146, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2111, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2049, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 1871, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 1795, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 372, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 326, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 280, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 229, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 183, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 137, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 65, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 577 to 2321, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2286, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2251, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2216, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2181, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2146, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2111, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2049, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 1871, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 1795, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 372, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 326, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 280, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 229, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 183, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 137, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 65, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 522 to 2321, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2286, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2251, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2216, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2181, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2146, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2111, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2049, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 1871, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 1795, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 372, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 326, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 280, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 229, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 183, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 137, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 65, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 1415 to 2321, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2286, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2251, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2216, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2181, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2146, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2111, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2049, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 1871, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 1795, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 372, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 326, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 280, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 229, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 183, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 137, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 65, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 985 to 2321, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2286, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2251, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2216, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2181, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2146, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2111, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2049, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 1871, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 1795, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 372, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 326, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 280, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 229, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 183, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 137, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 65, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 1871 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 856 to 2321, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2286, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2251, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2216, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2181, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2146, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2111, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2049, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 1871, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 1795, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 372, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 326, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 280, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 229, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 183, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 137, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 65, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 1795 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 706 to 2321, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2286, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2251, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2216, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2181, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2146, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2111, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2049, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 1871, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 1795, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 372, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 326, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 280, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 229, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 183, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 137, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 65, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 427 to 2321, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2286, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2251, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2216, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2181, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2146, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2111, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2049, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 1871, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 1795, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 372, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 326, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 280, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 229, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 183, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 137, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 65, Data: {'edge_label': 'Distance: 3703.49'}

# %%
def run_dfs(G, start_node):
    # Perform a DFS traversal from the start node
    visited_nodes = list(nx.dfs_preorder_nodes(G, source=start_node))
    visited_edges = list(nx.dfs_edges(G, source=start_node))

    print(f"DFS Node Visit Order: {visited_nodes}")
    print(f"DFS Edges Traversed: {visited_edges}")

    return visited_nodes, visited_edges


if __name__ == "__main__":
    # File path to the IFC file
    ifc_file_path = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\floorplanexampleroomswithnames.ifc'

    try:
        ifc_file = ifcopenshell.open(ifc_file_path)
    except Exception as e:
        raise FileNotFoundError(f"Error opening IFC file: {e}")

    # Create graph for walls, doors, and rooms
    G = create_graph(ifc_file)

    # Preprocess the graph attributes to ensure compatibility
    preprocess_graph_attributes(G)

    # Print vertices and edges
    print("Vertices:")
    for node_id, data in G.nodes(data=True):
        print(f"Node ID: {node_id}, Data: {data}")

    print("\nEdges:")
    for u, v, data in G.edges(data=True):
        print(f"Edge from {u} to {v}, Data: {data}")

    # Specify a start node for DFS
    start_node = list(G.nodes())[0]  # Start from the first node in the graph
    print(f"\nStarting DFS from Node: {start_node}")

    # Run DFS
    visited_nodes, visited_edges = run_dfs(G, start_node)

    # Draw the graph highlighting DFS traversal
    def visualize_dfs(G, visited_nodes, visited_edges):
        pos = nx.spring_layout(G, seed=42)

        # Highlight the nodes and edges in the DFS traversal
        node_colors = ['yellow' if node in visited_nodes else 'lightblue' for node in G.nodes()]
        edge_colors = ['red' if edge in visited_edges else 'black' for edge in G.edges()]

        # Draw the graph
        nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=500)
        nx.draw_networkx_edges(G, pos, edge_color=edge_colors, width=2)
        nx.draw_networkx_labels(G, pos, labels=nx.get_node_attributes(G, 'label'), font_size=10)
        plt.title("DFS Traversal Visualization")
        plt.show()

    visualize_dfs(G, visited_nodes, visited_edges)
# Out:
# Vertices:
# Node ID: 2321, Data: {'id': 2321, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVlI', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3049=IfcLocalPlacement(#3039,#3048)', 'Representation': '#2317=IfcProductDefinitionShape($,$,(#2316))', 'Tag': '1664109', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2286, Data: {'id': 2286, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVkU', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3029=IfcLocalPlacement(#3019,#3028)', 'Representation': '#2282=IfcProductDefinitionShape($,$,(#2281))', 'Tag': '1664033', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000017}
# Node ID: 2251, Data: {'id': 2251, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVn0', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3009=IfcLocalPlacement(#2999,#3008)', 'Representation': '#2247=IfcProductDefinitionShape($,$,(#2246))', 'Tag': '1663999', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000017}
# Node ID: 2216, Data: {'id': 2216, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVm6', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2989=IfcLocalPlacement(#2979,#2988)', 'Representation': '#2212=IfcProductDefinitionShape($,$,(#2211))', 'Tag': '1663929', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2181, Data: {'id': 2181, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVpw', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2969=IfcLocalPlacement(#2959,#2968)', 'Representation': '#2177=IfcProductDefinitionShape($,$,(#2176))', 'Tag': '1663813', 'OverallHeight': 2100.0, 'OverallWidth': 849.9999999999995}
# Node ID: 2146, Data: {'id': 2146, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVou', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2929=IfcLocalPlacement(#2919,#2928)', 'Representation': '#2142=IfcProductDefinitionShape($,$,(#2141))', 'Tag': '1663751', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000006}
# Node ID: 2111, Data: {'id': 2111, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVr_', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2949=IfcLocalPlacement(#2939,#2948)', 'Representation': '#2107=IfcProductDefinitionShape($,$,(#2106))', 'Tag': '1663681', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2049, Data: {'id': 2049, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVqh', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2909=IfcLocalPlacement(#2899,#2908)', 'Representation': '#2045=IfcProductDefinitionShape($,$,(#2044))', 'Tag': '1663636', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 1587, Data: {'id': 1587, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyS8f', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1575=IfcLocalPlacement(#34,#1574)', 'Representation': '#1586=IfcProductDefinitionShape($,$,(#1578,#1585))', 'Tag': '1662358'}
# Node ID: 1544, Data: {'id': 1544, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySAE', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1532=IfcLocalPlacement(#34,#1531)', 'Representation': '#1543=IfcProductDefinitionShape($,$,(#1535,#1542))', 'Tag': '1662257'}
# Node ID: 1501, Data: {'id': 1501, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySFq', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1489=IfcLocalPlacement(#34,#1488)', 'Representation': '#1500=IfcProductDefinitionShape($,$,(#1492,#1499))', 'Tag': '1662027'}
# Node ID: 1458, Data: {'id': 1458, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySGS', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1446=IfcLocalPlacement(#34,#1445)', 'Representation': '#1457=IfcProductDefinitionShape($,$,(#1449,#1456))', 'Tag': '1661859'}
# Node ID: 1372, Data: {'id': 1372, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySLf', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1360=IfcLocalPlacement(#34,#1359)', 'Representation': '#1371=IfcProductDefinitionShape($,$,(#1363,#1370))', 'Tag': '1661654'}
# Node ID: 1329, Data: {'id': 1329, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySNJ', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1317=IfcLocalPlacement(#34,#1316)', 'Representation': '#1328=IfcProductDefinitionShape($,$,(#1320,#1327))', 'Tag': '1661548'}
# Node ID: 1286, Data: {'id': 1286, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySML', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1274=IfcLocalPlacement(#34,#1273)', 'Representation': '#1285=IfcProductDefinitionShape($,$,(#1277,#1284))', 'Tag': '1661482'}
# Node ID: 1243, Data: {'id': 1243, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySPs', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1231=IfcLocalPlacement(#34,#1230)', 'Representation': '#1242=IfcProductDefinitionShape($,$,(#1234,#1241))', 'Tag': '1661385'}
# Node ID: 1200, Data: {'id': 1200, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySR7', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1188=IfcLocalPlacement(#34,#1187)', 'Representation': '#1199=IfcProductDefinitionShape($,$,(#1191,#1198))', 'Tag': '1661304'}
# Node ID: 1157, Data: {'id': 1157, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySaA', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1145=IfcLocalPlacement(#34,#1144)', 'Representation': '#1156=IfcProductDefinitionShape($,$,(#1148,#1155))', 'Tag': '1660597'}
# Node ID: 1114, Data: {'id': 1114, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySdv', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1102=IfcLocalPlacement(#34,#1101)', 'Representation': '#1113=IfcProductDefinitionShape($,$,(#1105,#1112))', 'Tag': '1660486'}
# Node ID: 1071, Data: {'id': 1071, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyScM', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1059=IfcLocalPlacement(#34,#1058)', 'Representation': '#1070=IfcProductDefinitionShape($,$,(#1062,#1069))', 'Tag': '1660457'}
# Node ID: 1028, Data: {'id': 1028, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySeJ', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1016=IfcLocalPlacement(#34,#1015)', 'Representation': '#1027=IfcProductDefinitionShape($,$,(#1019,#1026))', 'Tag': '1660332'}
# Node ID: 942, Data: {'id': 942, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySg$', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#930=IfcLocalPlacement(#34,#929)', 'Representation': '#941=IfcProductDefinitionShape($,$,(#933,#940))', 'Tag': '1660160'}
# Node ID: 899, Data: {'id': 899, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySkG', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#887=IfcLocalPlacement(#34,#886)', 'Representation': '#898=IfcProductDefinitionShape($,$,(#890,#897))', 'Tag': '1659951'}
# Node ID: 813, Data: {'id': 813, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySmj', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#801=IfcLocalPlacement(#34,#800)', 'Representation': '#812=IfcProductDefinitionShape($,$,(#804,#811))', 'Tag': '1659794'}
# Node ID: 770, Data: {'id': 770, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySr2', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#758=IfcLocalPlacement(#34,#757)', 'Representation': '#769=IfcProductDefinitionShape($,$,(#761,#768))', 'Tag': '1659645'}
# Node ID: 663, Data: {'id': 663, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySwl', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#651=IfcLocalPlacement(#34,#650)', 'Representation': '#662=IfcProductDefinitionShape($,$,(#654,#661))', 'Tag': '1659152'}
# Node ID: 577, Data: {'id': 577, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySy4', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Concrete 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Concrete 300mm', 'ObjectPlacement': '#561=IfcLocalPlacement(#34,#560)', 'Representation': '#576=IfcProductDefinitionShape($,$,(#564,#575))', 'Tag': '1659067'}
# Node ID: 522, Data: {'id': 522, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyS_Q', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#510=IfcLocalPlacement(#34,#509)', 'Representation': '#521=IfcProductDefinitionShape($,$,(#513,#520))', 'Tag': '1658917'}
# Node ID: 1415, Data: {'id': 1415, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySIs', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1403=IfcLocalPlacement(#34,#1402)', 'Representation': '#1414=IfcProductDefinitionShape($,$,(#1406,#1413))', 'Tag': '1661705'}
# Node ID: 985, Data: {'id': 985, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyShr', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#973=IfcLocalPlacement(#34,#972)', 'Representation': '#984=IfcProductDefinitionShape($,$,(#976,#983))', 'Tag': '1660234'}
# Node ID: 372, Data: {'id': 372, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVN', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '106', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#364=IfcLocalPlacement(#34,#363)', 'Representation': '#371=IfcProductDefinitionShape($,$,(#370))', 'LongName': 'Exam room 5', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '106'}
# Node ID: 326, Data: {'id': 326, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVI', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '105', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#318=IfcLocalPlacement(#34,#317)', 'Representation': '#325=IfcProductDefinitionShape($,$,(#324))', 'LongName': 'Exam room 4', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '105'}
# Node ID: 280, Data: {'id': 280, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVH', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '104', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#267=IfcLocalPlacement(#34,#266)', 'Representation': '#279=IfcProductDefinitionShape($,$,(#278))', 'LongName': 'Exam room 3', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '104'}
# Node ID: 1871, Data: {'id': 1871, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyS5V', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Double-Flush : 1700 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Double-Flush:1700 x 2000mm', 'ObjectPlacement': '#2889=IfcLocalPlacement(#2879,#2888)', 'Representation': '#1867=IfcProductDefinitionShape($,$,(#1866))', 'Tag': '1662688', 'OverallHeight': 2100.0, 'OverallWidth': 1799.9999999999989}
# Node ID: 856, Data: {'id': 856, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySn5', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#844=IfcLocalPlacement(#34,#843)', 'Representation': '#855=IfcProductDefinitionShape($,$,(#847,#854))', 'Tag': '1659898'}
# Node ID: 229, Data: {'id': 229, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVC', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '103', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#221=IfcLocalPlacement(#34,#220)', 'Representation': '#228=IfcProductDefinitionShape($,$,(#227))', 'LongName': 'Reception', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '103'}
# Node ID: 1795, Data: {'id': 1795, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyS6y', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Double-Flush : 1700 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Double-Flush:1700 x 2000mm', 'ObjectPlacement': '#2869=IfcLocalPlacement(#2859,#2868)', 'Representation': '#1791=IfcProductDefinitionShape($,$,(#1790))', 'Tag': '1662467', 'OverallHeight': 2100.0, 'OverallWidth': 1799.9999999999995}
# Node ID: 183, Data: {'id': 183, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVB', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '102', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#175=IfcLocalPlacement(#34,#174)', 'Representation': '#182=IfcProductDefinitionShape($,$,(#181))', 'LongName': 'Exam room 2', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '102'}
# Node ID: 137, Data: {'id': 137, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJV6', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '101', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#129=IfcLocalPlacement(#34,#128)', 'Representation': '#136=IfcProductDefinitionShape($,$,(#135))', 'LongName': 'Toilet', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '101'}
# Node ID: 706, Data: {'id': 706, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySqF', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#694=IfcLocalPlacement(#34,#693)', 'Representation': '#705=IfcProductDefinitionShape($,$,(#697,#704))', 'Tag': '1659568'}
# Node ID: 65, Data: {'id': 65, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJV5', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '100', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#57=IfcLocalPlacement(#34,#56)', 'Representation': '#64=IfcProductDefinitionShape($,$,(#63))', 'LongName': 'Exam room 1', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '100'}
# Node ID: 427, Data: {'id': 427, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyT1P', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#411=IfcLocalPlacement(#34,#410)', 'Representation': '#426=IfcProductDefinitionShape($,$,(#414,#425))', 'Tag': '1658854'}
#
# Edges:
# Edge from 2321 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1587 to 2321, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2286, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2251, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2216, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2181, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2146, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2111, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2049, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 1871, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 1795, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 372, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 326, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 280, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 229, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 183, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 137, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 65, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1544 to 2321, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2286, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2251, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2216, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2181, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2146, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2111, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2049, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 1871, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 1795, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 372, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 326, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 280, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 229, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 183, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 137, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 65, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1501 to 2321, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2286, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2251, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2216, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2181, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2146, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2111, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2049, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 1871, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 1795, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 372, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 326, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 280, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 229, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 183, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 137, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 65, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1458 to 2321, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2286, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2251, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2216, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2181, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2146, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2111, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2049, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 1871, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 1795, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 372, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 326, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 280, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 229, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 183, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 137, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 65, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1372 to 2321, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2286, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2251, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2216, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2181, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2146, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2111, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2049, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 1871, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 1795, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 372, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 326, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 280, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 229, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 183, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 137, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 65, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1329 to 2321, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2286, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2251, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2216, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2181, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2146, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2111, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2049, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 1871, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 1795, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 372, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 326, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 280, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 229, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 183, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 137, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 65, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1286 to 2321, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2286, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2251, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2216, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2181, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2146, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2111, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2049, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 1871, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 1795, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 372, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 326, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 280, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 229, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 183, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 137, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 65, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1243 to 2321, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2286, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2251, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2216, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2181, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2146, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2111, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2049, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 1871, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 1795, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 372, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 326, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 280, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 229, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 183, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 137, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 65, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1200 to 2321, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2286, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2251, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2216, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2181, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2146, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2111, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2049, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 1871, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 1795, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 372, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 326, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 280, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 229, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 183, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 137, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 65, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1157 to 2321, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2286, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2251, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2216, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2181, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2146, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2111, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2049, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 1871, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 1795, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 372, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 326, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 280, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 229, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 183, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 137, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 65, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1114 to 2321, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2286, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2251, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2216, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2181, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2146, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2111, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2049, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 1871, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 1795, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 372, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 326, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 280, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 229, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 183, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 137, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 65, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1071 to 2321, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2286, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2251, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2216, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2181, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2146, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2111, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2049, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 1871, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 1795, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 372, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 326, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 280, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 229, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 183, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 137, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 65, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1028 to 2321, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2286, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2251, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2216, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2181, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2146, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2111, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2049, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 1871, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 1795, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 372, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 326, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 280, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 229, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 183, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 137, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 65, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 942 to 2321, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2286, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2251, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2216, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2181, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2146, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2111, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2049, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 1871, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 1795, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 372, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 326, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 280, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 229, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 183, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 137, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 65, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 899 to 2321, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2286, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2251, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2216, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2181, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2146, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2111, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2049, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 1871, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 1795, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 372, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 326, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 280, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 229, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 183, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 137, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 65, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 813 to 2321, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2286, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2251, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2216, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2181, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2146, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2111, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2049, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 1871, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 1795, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 372, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 326, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 280, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 229, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 183, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 137, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 65, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 770 to 2321, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2286, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2251, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2216, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2181, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2146, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2111, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2049, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 1871, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 1795, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 372, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 326, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 280, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 229, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 183, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 137, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 65, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 663 to 2321, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2286, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2251, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2216, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2181, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2146, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2111, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2049, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 1871, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 1795, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 372, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 326, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 280, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 229, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 183, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 137, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 65, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 577 to 2321, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2286, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2251, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2216, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2181, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2146, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2111, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2049, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 1871, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 1795, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 372, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 326, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 280, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 229, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 183, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 137, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 65, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 522 to 2321, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2286, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2251, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2216, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2181, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2146, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2111, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2049, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 1871, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 1795, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 372, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 326, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 280, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 229, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 183, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 137, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 65, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 1415 to 2321, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2286, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2251, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2216, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2181, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2146, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2111, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2049, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 1871, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 1795, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 372, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 326, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 280, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 229, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 183, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 137, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 65, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 985 to 2321, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2286, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2251, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2216, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2181, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2146, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2111, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2049, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 1871, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 1795, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 372, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 326, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 280, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 229, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 183, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 137, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 65, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 1871 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 856 to 2321, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2286, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2251, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2216, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2181, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2146, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2111, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2049, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 1871, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 1795, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 372, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 326, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 280, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 229, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 183, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 137, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 65, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 1795 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 706 to 2321, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2286, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2251, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2216, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2181, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2146, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2111, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2049, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 1871, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 1795, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 372, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 326, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 280, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 229, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 183, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 137, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 65, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 427 to 2321, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2286, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2251, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2216, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2181, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2146, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2111, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2049, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 1871, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 1795, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 372, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 326, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 280, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 229, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 183, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 137, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 65, Data: {'edge_label': 'Distance: 3703.49'}
#
# Starting DFS from Node: 2321
# DFS Node Visit Order: [2321, 372, 326, 280, 229, 183, 137, 65]
# DFS Edges Traversed: [(2321, 372), (2321, 326), (2321, 280), (2321, 229), (2321, 183), (2321, 137), (2321, 65)]

# %%
import csv
from collections import defaultdict

class UnionFind:
    """
    A simple Union-Find (Disjoint Set) implementation
    """
    def __init__(self):
        self.parent = {}
        self.rank = {}
    
    def find(self, item):
        # Path compression optimization
        if self.parent[item] != item:
            self.parent[item] = self.find(self.parent[item])
        return self.parent[item]
    
    def union(self, a, b):
        rootA = self.find(a)
        rootB = self.find(b)
        
        if rootA != rootB:
            # Union by rank optimization
            if self.rank[rootA] < self.rank[rootB]:
                self.parent[rootA] = rootB
            elif self.rank[rootA] > self.rank[rootB]:
                self.parent[rootB] = rootA
            else:
                self.parent[rootB] = rootA
                self.rank[rootA] += 1
    
    def add(self, item):
        # Add an element if it’s not already present
        if item not in self.parent:
            self.parent[item] = item
            self.rank[item] = 0


def merge_zero_distance_nodes(input_csv, output_csv):
    uf = UnionFind()

    input_csv = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\edges.csv'
    
    edges = []
    
    # 1. Read CSV and populate union-find structure
    with open(input_csv, mode='r', newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        
        for row in reader:
            source = row['Source']
            target = row['Target']
            distance = float(row['Distance'])
            
            # Add nodes to union-find
            uf.add(source)
            uf.add(target)
            
            # Store the edge to rebuild later
            edges.append((source, target, distance))
            
            # If distance=0.0, union these nodes
            if distance == 0.0:
                uf.union(source, target)
    
    # 2. Generate a final mapping from each node to its representative
    representative_map = {}
    for node in uf.parent.keys():    
        rep = uf.find(node)
        representative_map[node] = rep
    
    # 3. Re-map edges to their representatives
    merged_edges = []
    for (source, target, distance) in edges:
        new_source = representative_map[source]
        new_target = representative_map[target]
        
        # If the source and target are the same after merging,
        # it’s effectively a self-loop. Decide if you keep or skip it.
        if new_source != new_target:
            merged_edges.append((new_source, new_target, distance))
    
    # 4. Deduplicate by converting list to a set (if order doesn’t matter).
    #    Otherwise, you might keep it a list and skip duplicates manually.
    merged_edges = list(set(merged_edges))
    
    # 5. Write the output CSV
    with open(output_csv, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["Source","Target","Distance"])
        for src, tgt, dist in merged_edges:
            writer.writerow([src, tgt, dist])


# Usage
merge_zero_distance_nodes("edges.csv", "edges_merged.csv")

# %%
def run_dfs_with_disconnected_nodes(G):
    visited = set()
    traversal = []

    def dfs(node):
        stack = [node]
        while stack:
            current = stack.pop()
            if current not in visited:
                visited.add(current)
                traversal.append(current)
                stack.extend(n for n in G.neighbors(current) if n not in visited)

    # Loop through all nodes to ensure disconnected ones are included
    for node in G.nodes():
        if node not in visited:
            dfs(node)

    return traversal


if __name__ == "__main__":
    # File path to the IFC file
    ifc_file_path = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\floorplanexampleroomswithnames.ifc'

    try:
        ifc_file = ifcopenshell.open(ifc_file_path)
    except Exception as e:
        raise FileNotFoundError(f"Error opening IFC file: {e}")

    # Create graph for walls, doors, and rooms
    G = create_graph(ifc_file)

    # Preprocess the graph attributes to ensure compatibility
    preprocess_graph_attributes(G)

    # Print vertices and edges
    print("Vertices:")
    for node_id, data in G.nodes(data=True):
        print(f"Node ID: {node_id}, Data: {data}")

    print("\nEdges:")
    for u, v, data in G.edges(data=True):
        print(f"Edge from {u} to {v}, Data: {data}")

    # Run DFS including disconnected nodes
    dfs_traversal = run_dfs_with_disconnected_nodes(G)
    print("\nDFS Traversal (Including Disconnected Nodes):")
    print(dfs_traversal)
# Out:
# Vertices:
# Node ID: 2321, Data: {'id': 2321, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVlI', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3049=IfcLocalPlacement(#3039,#3048)', 'Representation': '#2317=IfcProductDefinitionShape($,$,(#2316))', 'Tag': '1664109', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2286, Data: {'id': 2286, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVkU', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3029=IfcLocalPlacement(#3019,#3028)', 'Representation': '#2282=IfcProductDefinitionShape($,$,(#2281))', 'Tag': '1664033', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000017}
# Node ID: 2251, Data: {'id': 2251, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVn0', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#3009=IfcLocalPlacement(#2999,#3008)', 'Representation': '#2247=IfcProductDefinitionShape($,$,(#2246))', 'Tag': '1663999', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000017}
# Node ID: 2216, Data: {'id': 2216, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVm6', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2989=IfcLocalPlacement(#2979,#2988)', 'Representation': '#2212=IfcProductDefinitionShape($,$,(#2211))', 'Tag': '1663929', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2181, Data: {'id': 2181, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVpw', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2969=IfcLocalPlacement(#2959,#2968)', 'Representation': '#2177=IfcProductDefinitionShape($,$,(#2176))', 'Tag': '1663813', 'OverallHeight': 2100.0, 'OverallWidth': 849.9999999999995}
# Node ID: 2146, Data: {'id': 2146, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVou', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2929=IfcLocalPlacement(#2919,#2928)', 'Representation': '#2142=IfcProductDefinitionShape($,$,(#2141))', 'Tag': '1663751', 'OverallHeight': 2100.0, 'OverallWidth': 850.0000000000006}
# Node ID: 2111, Data: {'id': 2111, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVr_', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2949=IfcLocalPlacement(#2939,#2948)', 'Representation': '#2107=IfcProductDefinitionShape($,$,(#2106))', 'Tag': '1663681', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 2049, Data: {'id': 2049, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyVqh', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Single-Flush : 750 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Single-Flush:750 x 2000mm', 'ObjectPlacement': '#2909=IfcLocalPlacement(#2899,#2908)', 'Representation': '#2045=IfcProductDefinitionShape($,$,(#2044))', 'Tag': '1663636', 'OverallHeight': 2100.0, 'OverallWidth': 850.0}
# Node ID: 1587, Data: {'id': 1587, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyS8f', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1575=IfcLocalPlacement(#34,#1574)', 'Representation': '#1586=IfcProductDefinitionShape($,$,(#1578,#1585))', 'Tag': '1662358'}
# Node ID: 1544, Data: {'id': 1544, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySAE', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1532=IfcLocalPlacement(#34,#1531)', 'Representation': '#1543=IfcProductDefinitionShape($,$,(#1535,#1542))', 'Tag': '1662257'}
# Node ID: 1501, Data: {'id': 1501, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySFq', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1489=IfcLocalPlacement(#34,#1488)', 'Representation': '#1500=IfcProductDefinitionShape($,$,(#1492,#1499))', 'Tag': '1662027'}
# Node ID: 1458, Data: {'id': 1458, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySGS', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1446=IfcLocalPlacement(#34,#1445)', 'Representation': '#1457=IfcProductDefinitionShape($,$,(#1449,#1456))', 'Tag': '1661859'}
# Node ID: 1372, Data: {'id': 1372, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySLf', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1360=IfcLocalPlacement(#34,#1359)', 'Representation': '#1371=IfcProductDefinitionShape($,$,(#1363,#1370))', 'Tag': '1661654'}
# Node ID: 1329, Data: {'id': 1329, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySNJ', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1317=IfcLocalPlacement(#34,#1316)', 'Representation': '#1328=IfcProductDefinitionShape($,$,(#1320,#1327))', 'Tag': '1661548'}
# Node ID: 1286, Data: {'id': 1286, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySML', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1274=IfcLocalPlacement(#34,#1273)', 'Representation': '#1285=IfcProductDefinitionShape($,$,(#1277,#1284))', 'Tag': '1661482'}
# Node ID: 1243, Data: {'id': 1243, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySPs', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1231=IfcLocalPlacement(#34,#1230)', 'Representation': '#1242=IfcProductDefinitionShape($,$,(#1234,#1241))', 'Tag': '1661385'}
# Node ID: 1200, Data: {'id': 1200, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySR7', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1188=IfcLocalPlacement(#34,#1187)', 'Representation': '#1199=IfcProductDefinitionShape($,$,(#1191,#1198))', 'Tag': '1661304'}
# Node ID: 1157, Data: {'id': 1157, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySaA', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1145=IfcLocalPlacement(#34,#1144)', 'Representation': '#1156=IfcProductDefinitionShape($,$,(#1148,#1155))', 'Tag': '1660597'}
# Node ID: 1114, Data: {'id': 1114, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySdv', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1102=IfcLocalPlacement(#34,#1101)', 'Representation': '#1113=IfcProductDefinitionShape($,$,(#1105,#1112))', 'Tag': '1660486'}
# Node ID: 1071, Data: {'id': 1071, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyScM', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1059=IfcLocalPlacement(#34,#1058)', 'Representation': '#1070=IfcProductDefinitionShape($,$,(#1062,#1069))', 'Tag': '1660457'}
# Node ID: 1028, Data: {'id': 1028, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySeJ', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1016=IfcLocalPlacement(#34,#1015)', 'Representation': '#1027=IfcProductDefinitionShape($,$,(#1019,#1026))', 'Tag': '1660332'}
# Node ID: 942, Data: {'id': 942, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySg$', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#930=IfcLocalPlacement(#34,#929)', 'Representation': '#941=IfcProductDefinitionShape($,$,(#933,#940))', 'Tag': '1660160'}
# Node ID: 899, Data: {'id': 899, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySkG', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#887=IfcLocalPlacement(#34,#886)', 'Representation': '#898=IfcProductDefinitionShape($,$,(#890,#897))', 'Tag': '1659951'}
# Node ID: 813, Data: {'id': 813, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySmj', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#801=IfcLocalPlacement(#34,#800)', 'Representation': '#812=IfcProductDefinitionShape($,$,(#804,#811))', 'Tag': '1659794'}
# Node ID: 770, Data: {'id': 770, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySr2', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#758=IfcLocalPlacement(#34,#757)', 'Representation': '#769=IfcProductDefinitionShape($,$,(#761,#768))', 'Tag': '1659645'}
# Node ID: 663, Data: {'id': 663, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySwl', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#651=IfcLocalPlacement(#34,#650)', 'Representation': '#662=IfcProductDefinitionShape($,$,(#654,#661))', 'Tag': '1659152'}
# Node ID: 577, Data: {'id': 577, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySy4', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Concrete 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Concrete 300mm', 'ObjectPlacement': '#561=IfcLocalPlacement(#34,#560)', 'Representation': '#576=IfcProductDefinitionShape($,$,(#564,#575))', 'Tag': '1659067'}
# Node ID: 522, Data: {'id': 522, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyS_Q', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#510=IfcLocalPlacement(#34,#509)', 'Representation': '#521=IfcProductDefinitionShape($,$,(#513,#520))', 'Tag': '1658917'}
# Node ID: 1415, Data: {'id': 1415, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySIs', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#1403=IfcLocalPlacement(#34,#1402)', 'Representation': '#1414=IfcProductDefinitionShape($,$,(#1406,#1413))', 'Tag': '1661705'}
# Node ID: 985, Data: {'id': 985, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyShr', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#973=IfcLocalPlacement(#34,#972)', 'Representation': '#984=IfcProductDefinitionShape($,$,(#976,#983))', 'Tag': '1660234'}
# Node ID: 372, Data: {'id': 372, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVN', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '106', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#364=IfcLocalPlacement(#34,#363)', 'Representation': '#371=IfcProductDefinitionShape($,$,(#370))', 'LongName': 'Exam room 5', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '106'}
# Node ID: 326, Data: {'id': 326, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVI', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '105', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#318=IfcLocalPlacement(#34,#317)', 'Representation': '#325=IfcProductDefinitionShape($,$,(#324))', 'LongName': 'Exam room 4', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '105'}
# Node ID: 280, Data: {'id': 280, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVH', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '104', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#267=IfcLocalPlacement(#34,#266)', 'Representation': '#279=IfcProductDefinitionShape($,$,(#278))', 'LongName': 'Exam room 3', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '104'}
# Node ID: 1871, Data: {'id': 1871, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyS5V', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Double-Flush : 1700 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Double-Flush:1700 x 2000mm', 'ObjectPlacement': '#2889=IfcLocalPlacement(#2879,#2888)', 'Representation': '#1867=IfcProductDefinitionShape($,$,(#1866))', 'Tag': '1662688', 'OverallHeight': 2100.0, 'OverallWidth': 1799.9999999999989}
# Node ID: 856, Data: {'id': 856, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySn5', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#844=IfcLocalPlacement(#34,#843)', 'Representation': '#855=IfcProductDefinitionShape($,$,(#847,#854))', 'Tag': '1659898'}
# Node ID: 229, Data: {'id': 229, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVC', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '103', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#221=IfcLocalPlacement(#34,#220)', 'Representation': '#228=IfcProductDefinitionShape($,$,(#227))', 'LongName': 'Reception', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '103'}
# Node ID: 1795, Data: {'id': 1795, 'type': 'IfcDoor', 'GlobalId': '16myiqVj55HBwjlpwIyS6y', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Doors : M_Door-Passage-Double-Flush : 1700 x 2000mm', 'Description': None, 'ObjectType': 'M_Door-Passage-Double-Flush:1700 x 2000mm', 'ObjectPlacement': '#2869=IfcLocalPlacement(#2859,#2868)', 'Representation': '#1791=IfcProductDefinitionShape($,$,(#1790))', 'Tag': '1662467', 'OverallHeight': 2100.0, 'OverallWidth': 1799.9999999999995}
# Node ID: 183, Data: {'id': 183, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJVB', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '102', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#175=IfcLocalPlacement(#34,#174)', 'Representation': '#182=IfcProductDefinitionShape($,$,(#181))', 'LongName': 'Exam room 2', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '102'}
# Node ID: 137, Data: {'id': 137, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJV6', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '101', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#129=IfcLocalPlacement(#34,#128)', 'Representation': '#136=IfcProductDefinitionShape($,$,(#135))', 'LongName': 'Toilet', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '101'}
# Node ID: 706, Data: {'id': 706, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIySqF', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 200mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 200mm', 'ObjectPlacement': '#694=IfcLocalPlacement(#34,#693)', 'Representation': '#705=IfcProductDefinitionShape($,$,(#697,#704))', 'Tag': '1659568'}
# Node ID: 65, Data: {'id': 65, 'type': 'IfcSpace', 'GlobalId': '1nF85ctCLA4vpOeu$UGJV5', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': '100', 'Description': None, 'ObjectType': None, 'ObjectPlacement': '#57=IfcLocalPlacement(#34,#56)', 'Representation': '#64=IfcProductDefinitionShape($,$,(#63))', 'LongName': 'Exam room 1', 'CompositionType': 'ELEMENT', 'InteriorOrExteriorSpace': 'INTERNAL', 'ElevationWithFlooring': None, 'label': '100'}
# Node ID: 427, Data: {'id': 427, 'type': 'IfcWallStandardCase', 'GlobalId': '16myiqVj55HBwjlpwIyT1P', 'OwnerHistory': '#18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1734033119)', 'Name': 'Walls : Basic Wall : Generic - 300mm', 'Description': None, 'ObjectType': 'Basic Wall:Generic - 300mm', 'ObjectPlacement': '#411=IfcLocalPlacement(#34,#410)', 'Representation': '#426=IfcProductDefinitionShape($,$,(#414,#425))', 'Tag': '1658854'}
#
# Edges:
# Edge from 2321 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2321 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2286 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2251 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2216 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2181 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2146 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2111 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 2049 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1587 to 2321, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2286, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2251, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2216, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2181, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2146, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2111, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 2049, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 1871, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 1795, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 372, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 326, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 280, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 229, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 183, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 137, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1587 to 65, Data: {'edge_label': 'Distance: 21343.99'}
# Edge from 1544 to 2321, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2286, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2251, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2216, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2181, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2146, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2111, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 2049, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 1871, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 1795, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 372, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 326, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 280, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 229, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 183, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 137, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1544 to 65, Data: {'edge_label': 'Distance: 26837.28'}
# Edge from 1501 to 2321, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2286, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2251, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2216, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2181, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2146, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2111, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 2049, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 1871, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 1795, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 372, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 326, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 280, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 229, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 183, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 137, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1501 to 65, Data: {'edge_label': 'Distance: 21331.66'}
# Edge from 1458 to 2321, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2286, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2251, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2216, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2181, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2146, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2111, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 2049, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 1871, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 1795, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 372, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 326, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 280, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 229, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 183, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 137, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1458 to 65, Data: {'edge_label': 'Distance: 21526.47'}
# Edge from 1372 to 2321, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2286, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2251, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2216, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2181, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2146, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2111, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 2049, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 1871, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 1795, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 372, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 326, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 280, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 229, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 183, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 137, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1372 to 65, Data: {'edge_label': 'Distance: 17760.20'}
# Edge from 1329 to 2321, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2286, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2251, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2216, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2181, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2146, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2111, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 2049, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 1871, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 1795, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 372, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 326, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 280, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 229, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 183, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 137, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1329 to 65, Data: {'edge_label': 'Distance: 20579.51'}
# Edge from 1286 to 2321, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2286, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2251, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2216, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2181, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2146, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2111, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 2049, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 1871, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 1795, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 372, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 326, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 280, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 229, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 183, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 137, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1286 to 65, Data: {'edge_label': 'Distance: 20221.16'}
# Edge from 1243 to 2321, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2286, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2251, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2216, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2181, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2146, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2111, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 2049, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 1871, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 1795, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 372, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 326, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 280, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 229, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 183, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 137, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1243 to 65, Data: {'edge_label': 'Distance: 15822.52'}
# Edge from 1200 to 2321, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2286, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2251, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2216, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2181, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2146, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2111, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 2049, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 1871, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 1795, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 372, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 326, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 280, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 229, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 183, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 137, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1200 to 65, Data: {'edge_label': 'Distance: 15595.88'}
# Edge from 1157 to 2321, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2286, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2251, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2216, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2181, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2146, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2111, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 2049, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 1871, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 1795, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 372, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 326, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 280, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 229, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 183, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 137, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1157 to 65, Data: {'edge_label': 'Distance: 16096.35'}
# Edge from 1114 to 2321, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2286, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2251, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2216, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2181, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2146, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2111, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 2049, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 1871, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 1795, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 372, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 326, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 280, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 229, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 183, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 137, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1114 to 65, Data: {'edge_label': 'Distance: 16700.46'}
# Edge from 1071 to 2321, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2286, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2251, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2216, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2181, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2146, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2111, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 2049, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 1871, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 1795, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 372, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 326, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 280, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 229, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 183, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 137, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1071 to 65, Data: {'edge_label': 'Distance: 8938.87'}
# Edge from 1028 to 2321, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2286, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2251, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2216, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2181, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2146, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2111, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 2049, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 1871, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 1795, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 372, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 326, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 280, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 229, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 183, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 137, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 1028 to 65, Data: {'edge_label': 'Distance: 7828.93'}
# Edge from 942 to 2321, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2286, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2251, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2216, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2181, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2146, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2111, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 2049, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 1871, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 1795, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 372, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 326, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 280, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 229, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 183, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 137, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 942 to 65, Data: {'edge_label': 'Distance: 2173.69'}
# Edge from 899 to 2321, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2286, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2251, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2216, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2181, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2146, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2111, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 2049, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 1871, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 1795, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 372, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 326, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 280, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 229, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 183, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 137, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 899 to 65, Data: {'edge_label': 'Distance: 13996.27'}
# Edge from 813 to 2321, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2286, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2251, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2216, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2181, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2146, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2111, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 2049, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 1871, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 1795, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 372, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 326, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 280, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 229, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 183, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 137, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 813 to 65, Data: {'edge_label': 'Distance: 7006.36'}
# Edge from 770 to 2321, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2286, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2251, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2216, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2181, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2146, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2111, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 2049, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 1871, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 1795, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 372, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 326, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 280, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 229, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 183, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 137, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 770 to 65, Data: {'edge_label': 'Distance: 3942.71'}
# Edge from 663 to 2321, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2286, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2251, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2216, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2181, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2146, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2111, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 2049, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 1871, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 1795, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 372, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 326, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 280, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 229, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 183, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 137, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 663 to 65, Data: {'edge_label': 'Distance: 5766.61'}
# Edge from 577 to 2321, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2286, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2251, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2216, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2181, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2146, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2111, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 2049, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 1871, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 1795, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 372, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 326, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 280, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 229, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 183, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 137, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 577 to 65, Data: {'edge_label': 'Distance: 27402.39'}
# Edge from 522 to 2321, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2286, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2251, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2216, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2181, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2146, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2111, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 2049, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 1871, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 1795, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 372, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 326, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 280, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 229, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 183, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 137, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 522 to 65, Data: {'edge_label': 'Distance: 27139.26'}
# Edge from 1415 to 2321, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2286, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2251, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2216, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2181, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2146, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2111, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 2049, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 1871, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 1795, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 372, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 326, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 280, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 229, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 183, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 137, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 1415 to 65, Data: {'edge_label': 'Distance: 17050.82'}
# Edge from 985 to 2321, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2286, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2251, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2216, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2181, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2146, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2111, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 2049, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 1871, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 1795, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 372, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 326, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 280, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 229, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 183, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 137, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 985 to 65, Data: {'edge_label': 'Distance: 6783.61'}
# Edge from 1871 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1871 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 856 to 2321, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2286, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2251, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2216, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2181, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2146, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2111, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 2049, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 1871, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 1795, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 372, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 326, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 280, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 229, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 183, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 137, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 856 to 65, Data: {'edge_label': 'Distance: 6144.92'}
# Edge from 1795 to 372, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 326, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 280, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 229, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 183, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 137, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 1795 to 65, Data: {'edge_label': 'Distance: 0.00'}
# Edge from 706 to 2321, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2286, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2251, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2216, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2181, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2146, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2111, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 2049, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 1871, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 1795, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 372, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 326, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 280, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 229, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 183, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 137, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 706 to 65, Data: {'edge_label': 'Distance: 284.83'}
# Edge from 427 to 2321, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2286, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2251, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2216, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2181, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2146, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2111, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 2049, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 1871, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 1795, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 372, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 326, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 280, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 229, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 183, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 137, Data: {'edge_label': 'Distance: 3703.49'}
# Edge from 427 to 65, Data: {'edge_label': 'Distance: 3703.49'}
#
# DFS Traversal (Including Disconnected Nodes):
# [2321, 65, 137, 183, 229, 280, 326, 372, 2286, 2251, 2216, 2181, 2146, 2111, 2049, 1587, 1795, 1871, 1544, 1501, 1458, 1372, 1329, 1286, 1243, 1200, 1157, 1114, 1071, 1028, 942, 899, 813, 770, 663, 577, 522, 1415, 985, 856, 706, 427]

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

def load_graph_from_csv(nodes_csv, edges_csv):
    # Load nodes and edges from CSV
    nodes_df = pd.read_csv(nodes_csv)
    edges_df = pd.read_csv(edges_csv)
    
    # Create a directed graph
    G = nx.DiGraph()
    
    # Add nodes
    for _, row in nodes_df.iterrows():
        G.add_node(row['Id'], **row.to_dict())
    
    # Add edges with weights
    for _, row in edges_df.iterrows():
        G.add_edge(row['Source'], row['Target'], weight=row['Distance'], Distance=row['Distance'])
    
    return G

def find_shortest_path(G, source, target):
    try:
        # Find the shortest path using Dijkstra's algorithm
        shortest_path = nx.dijkstra_path(G, source=source, target=target, weight='Distance')
        path_length = nx.dijkstra_path_length(G, source=source, target=target, weight='Distance')
        
        print(f"Shortest path from {source} to {target}: {shortest_path}")
        print(f"Total distance: {path_length:.2f}")
        return shortest_path, path_length
    except nx.NetworkXNoPath:
        print(f"No path found between {source} and {target}.")
        return None, None

def visualize_graph(G, shortest_path):
    pos = nx.spring_layout(G)  # Position nodes using spring layout
    plt.figure(figsize=(10, 7))
    
    # Draw the full graph
    nx.draw(G, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, alpha=0.8)
    
    # Highlight the shortest path
    if shortest_path:
        path_edges = list(zip(shortest_path, shortest_path[1:]))
        nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', width=2)
    
    # Draw edge labels for distances
    edge_labels = nx.get_edge_attributes(G, 'Distance')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    
    plt.title("Graph Visualization with Shortest Path Highlighted")
    plt.xlabel("X Coordinate")
    plt.ylabel("Y Coordinate")
    plt.show()

def export_graph_to_csv(G, nodes_csv_path, edges_csv_path):
    # Create nodes dataframe
    nodes_data = [{"Id": n, **G.nodes[n]} for n in G.nodes()]
    nodes_df = pd.DataFrame(nodes_data)

    # Create edges dataframe
    edges_data = [{"Source": u, "Target": v, **data} for u, v, data in G.edges(data=True)]
    edges_df = pd.DataFrame(edges_data)

    # Save to CSV
    nodes_df.to_csv(nodes_csv_path, index=False)
    edges_df.to_csv(edges_csv_path, index=False)

    print(f"Nodes saved to: {nodes_csv_path}")
    print(f"Edges saved to: {edges_csv_path}")

if __name__ == "__main__":
    # Input CSV files
    nodes_csv_path = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\nodes.csv'
    edges_csv_path = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\edges.csv'

    # Output CSV files
    output_nodes_csv = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\nodes_cleaned.csv'
    output_edges_csv = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\edges_cleaned.csv'

    # Load the graph from CSV files
    G = load_graph_from_csv(nodes_csv_path, edges_csv_path)

    # Specify source and target nodes
    source_node = int(input("Source node: "))
    target_node = int(input("Target node: "))
    
    # Find the shortest path
    shortest_path, path_length = find_shortest_path(G, source_node, target_node)
    
    # Visualize the graph and the shortest path
    visualize_graph(G, shortest_path)
    
    # Export the graph to new CSV files
    export_graph_to_csv(G, output_nodes_csv, output_edges_csv)
# Out:
# No path found between 2216 and 217.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[81], line 96
#      93 visualize_graph(G, shortest_path)
#      95 # Export the graph to new CSV files
# ---> 96 export_graph_to_csv(G, output_nodes_csv, output_edges_csv)
#
# Cell In[81], line 68, in export_graph_to_csv(G, nodes_csv_path, edges_csv_path)
#      66 # Save to CSV
#      67 nodes_df.to_csv(nodes_csv_path, index=False)
# ---> 68 edges_df.to_csv(edges_csv_path, index=False)
#      70 print(f"Nodes saved to: {nodes_csv_path}")
#      71 print(f"Edges saved to: {edges_csv_path}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'D:\\IaaC\\RESEARCH\\TRAINING\\IFC TO GRPAH\\IFC TO GRAPH_METHOD 3_ELEF\\REF\\edges_cleaned.csv'

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

def load_graph_from_csv(nodes_csv, edges_csv):
    # Load nodes and edges from CSV
    nodes_df = pd.read_csv(nodes_csv)
    edges_df = pd.read_csv(edges_csv)
    
    # Create a directed graph
    G = nx.DiGraph()
    
    # Add nodes
    for _, row in nodes_df.iterrows():
        G.add_node(row['Id'], **row.to_dict())
    
    # Add edges with distances as weights
    for _, row in edges_df.iterrows():
        G.add_edge(row['Source'], row['Target'], weight=row['Distance'])
    
    return G

def find_shortest_path(G, source, target):
    try:
        # Find the shortest path using Dijkstra's algorithm
        shortest_path = nx.dijkstra_path(G, source=source, target=target, weight='weight')
        path_length = nx.dijkstra_path_length(G, source=source, target=target, weight='weight')
        
        print(f"Shortest path from {source} to {target}: {shortest_path}")
        print(f"Total distance: {path_length:.2f}")
        return shortest_path, path_length
    except nx.NetworkXNoPath:
        print(f"No path found between {source} and {target}.")
        return None, None

def visualize_graph(G, shortest_path):
    pos = nx.spring_layout(G)  # Position nodes using spring layout
    plt.figure(figsize=(10, 7))
    
    # Draw the full graph
    nx.draw(G, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, alpha=0.8)
    
    # Highlight the shortest path
    if shortest_path:
        path_edges = list(zip(shortest_path, shortest_path[1:]))
        nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', width=2)
    
    # Draw edge labels for distances
    edge_labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    
    plt.title("Graph Visualization with Shortest Path Highlighted")
    plt.xlabel("X Coordinate")
    plt.ylabel("Y Coordinate")
    plt.show()

if __name__ == "__main__":
    # Input CSV files
    nodes_csv_path = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\nodes_cleaned.csv'  # Replace with your actual file path
    edges_csv_path = r'D:\IaaC\RESEARCH\TRAINING\IFC TO GRPAH\IFC TO GRAPH_METHOD 3_ELEF\REF\edges_cleaned.csv'  # Replace with your actual file path

    # Load the graph from CSV files
    G = load_graph_from_csv(nodes_csv_path, edges_csv_path)

    # Specify source and target nodes
    source_node = int(input("Source node: "))
    target_node = int(input("Target node: "))
    
    # Find the shortest path
    shortest_path, path_length = find_shortest_path(G, source_node, target_node)
    
    # Visualize the graph and the shortest path
    visualize_graph(G, shortest_path)
# Out:
# No path found between 2216 and 280.
